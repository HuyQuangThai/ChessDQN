# %%
from Table.MCControl import MCControl
from Env.ChessEnv import ChessEnv

# %%
env = ChessEnv()
agent = MCControl(epsilon=0.1, defaultQ=0)
agent.play()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 env = ChessEnv()
#       2 agent = MCControl(epsilon=0.1, defaultQ=0)
#       3 agent.play()
#
# NameError: name 'ChessEnv' is not defined
