# %%
from Table.MCControl import MCControl
from Env.ChessEnv import ChessEnv

# %%
env = ChessEnv()
agent = MCControl(epsilon=0.1, defaultQ=0)
agent.play()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 agent = MCControl(epsilon=0.1, defaultQ=0)
#       2 agent.play()
#
# TypeError: MCControl.__init__() missing 1 required positional argument: 'env'
